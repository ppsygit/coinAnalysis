# %%
import requests
import pandas as pd

url = "https://api.upbit.com/v1/candles/minutes/5?market=KRW-BTC&to=2024-07-01T12%3A00%3A00&count=144"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

df = pd.DataFrame(response.json()).sort_values('candle_date_time_utc').reset_index().drop(columns='index')

df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2024-07-01T00:00:00  2024-07-01T09:00:00     87920000.0
# 1    KRW-BTC  2024-07-01T00:05:00  2024-07-01T09:05:00     87953000.0
# 2    KRW-BTC  2024-07-01T00:10:00  2024-07-01T09:10:00     87786000.0
# 3    KRW-BTC  2024-07-01T00:15:00  2024-07-01T09:15:00     87671000.0
# 4    KRW-BTC  2024-07-01T00:20:00  2024-07-01T09:20:00     87775000.0
# ..       ...                  ...                  ...            ...
# 139  KRW-BTC  2024-07-01T11:35:00  2024-07-01T20:35:00     87781000.0
# 140  KRW-BTC  2024-07-01T11:40:00  2024-07-01T20:40:00     87793000.0
# 141  KRW-BTC  2024-07-01T11:45:00  2024-07-01T20:45:00     87820000.0
# 142  KRW-BTC  2024-07-01T11:50:00  2024-07-01T20:50:00     87797000.0
# 143  KRW-BTC  2024-07-01T11:55:00  2024-07-01T20:55:00     87654000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    88058000.0  87869000.0   87968000.0  1719792299879
# ...

# %%
import requests
import pandas as pd

url = "https://api.upbit.com/v1/candles/minutes/5?market=KRW-USDT&to=2024-07-01T23%3A59%3A00&count=144"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

df = pd.DataFrame(response.json()).sort_values('candle_date_time_utc').reset_index().drop(columns='index')

df
# Out:
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-USDT  2024-07-01T12:00:00  2024-07-01T21:00:00         1401.0
# 1    KRW-USDT  2024-07-01T12:05:00  2024-07-01T21:05:00         1401.0
# 2    KRW-USDT  2024-07-01T12:10:00  2024-07-01T21:10:00         1402.0
# 3    KRW-USDT  2024-07-01T12:15:00  2024-07-01T21:15:00         1402.0
# 4    KRW-USDT  2024-07-01T12:20:00  2024-07-01T21:20:00         1402.0
# ..        ...                  ...                  ...            ...
# 139  KRW-USDT  2024-07-01T23:35:00  2024-07-02T08:35:00         1405.0
# 140  KRW-USDT  2024-07-01T23:40:00  2024-07-02T08:40:00         1404.0
# 141  KRW-USDT  2024-07-01T23:45:00  2024-07-02T08:45:00         1405.0
# 142  KRW-USDT  2024-07-01T23:50:00  2024-07-02T08:50:00         1405.0
# 143  KRW-USDT  2024-07-01T23:55:00  2024-07-02T08:55:00         1405.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        1402.0     1400.0       1401.0  1719835498923
# ...

# %%
import requests
import pandas as pd

def get_5min_stick_of_1day(coin,date):

    url = f"https://api.upbit.com/v1/candles/minutes/5?market=KRW-{coin}&to={date}T12%3A00%3A00&count=144"
    headers = {"accept": "application/json"}
    response = requests.get(url, headers=headers)
    print(response)
    df = pd.DataFrame(response.json()).sort_values('candle_date_time_utc').reset_index().drop(columns='index')

    url = f"https://api.upbit.com/v1/candles/minutes/5?market=KRW-{coin}&to={date}T23%3A59%3A00&count=144"
    headers = {"accept": "application/json"}
    response = requests.get(url, headers=headers)
    df2 = pd.DataFrame(response.json()).sort_values('candle_date_time_utc').reset_index().drop(columns='index')

    result = pd.concat([df,df2]).reset_index().drop(columns='index')
    return result

# %%
df = get_5min_stick_of_1day('BTC','2024-07-02')
df
# Out:
# <Response [200]>
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2024-07-02T00:00:00  2024-07-02T09:00:00     88259000.0
# 1    KRW-BTC  2024-07-02T00:05:00  2024-07-02T09:05:00     88360000.0
# 2    KRW-BTC  2024-07-02T00:10:00  2024-07-02T09:10:00     88306000.0
# 3    KRW-BTC  2024-07-02T00:15:00  2024-07-02T09:15:00     88280000.0
# 4    KRW-BTC  2024-07-02T00:20:00  2024-07-02T09:20:00     88148000.0
# ..       ...                  ...                  ...            ...
# 283  KRW-BTC  2024-07-02T23:35:00  2024-07-03T08:35:00     87350000.0
# 284  KRW-BTC  2024-07-02T23:40:00  2024-07-03T08:40:00     87331000.0
# 285  KRW-BTC  2024-07-02T23:45:00  2024-07-03T08:45:00     87380000.0
# 286  KRW-BTC  2024-07-02T23:50:00  2024-07-03T08:50:00     87316000.0
# 287  KRW-BTC  2024-07-02T23:55:00  2024-07-03T08:55:00     87306000.0
#
#      high_price   low_price  trade_price      timestamp  \
# ...

# %%
from datetime import datetime, timedelta

def date_range(start, end):
    start = datetime.strptime(start, "%Y-%m-%d")
    end = datetime.strptime(end, "%Y-%m-%d")
    dates = [(start + timedelta(days=i)).strftime("%Y-%m-%d") for i in range((end-start).days+1)]
    return dates

dates = date_range("2024-06-01", "2024-07-01")
dates
# Out:
# ['2024-06-01',
#  '2024-06-02',
#  '2024-06-03',
#  '2024-06-04',
#  '2024-06-05',
#  '2024-06-06',
#  '2024-06-07',
#  '2024-06-08',
#  '2024-06-09',
#  '2024-06-10',
#  '2024-06-11',
#  '2024-06-12',
#  '2024-06-13',
#  '2024-06-14',
#  '2024-06-15',
#  '2024-06-16',
#  '2024-06-17',
#  '2024-06-18',
#  '2024-06-19',
#  '2024-06-20',
#  '2024-06-21',
#  '2024-06-22',
#  '2024-06-23',
#  '2024-06-24',
#  '2024-06-25',
#  '2024-06-26',
#  '2024-06-27',
#  '2024-06-28',
#  '2024-06-29',
#  '2024-06-30',
#  '2024-07-01']

# %%
def get_5min_stick_of_interval(coin, dates):
    df = pd.DataFrame()
    for date in dates:
        df2 = get_5min_stick_of_1day(coin,date)
        df = pd.concat([df,df2])
        print(date)
    return df.reset_index().drop(columns='index')

# %%
# 일주일 6초
dates = date_range("2023-06-27", "2024-07-01")
df = get_5min_stick_of_interval('BTC',dates)
df
# Out:
# <Response [200]>
# 2023-06-27
# <Response [200]>
# 2023-06-28
# <Response [200]>
# 2023-06-29
# <Response [200]>
# 2023-06-30
# <Response [200]>
# 2023-07-01
# <Response [200]>
# 2023-07-02
# <Response [200]>
# 2023-07-03
# <Response [200]>
# 2023-07-04
# <Response [200]>
# 2023-07-05
# <Response [200]>
# 2023-07-06
# <Response [200]>
# 2023-07-07
# <Response [200]>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # 일주일 6초
#       2 dates = date_range("2023-06-27", "2024-07-01")
# ----> 3 df = get_5min_stick_of_interval('BTC',dates)
#       4 df
#
# Cell In[4], line 4, in get_5min_stick_of_interval(coin, dates)
#       2 df = pd.DataFrame()
#       3 for date in dates:
# ----> 4     df2 = get_5min_stick_of_1day(coin,date)
#       5     df = pd.concat([df,df2])
#       6     print(date)
#
# Cell In[1], line 14, in get_5min_stick_of_1day(coin, date)
# ...

# %%
def get_5min_stick_of_interval_2023():
    dates = date_range("2023-06-27", "2024-07-01")
    df = get_5min_stick_of_interval('BTC',dates)
    df

# %%
dates = date_range("2023-07-16", "2024-07-16")
df = get_5min_stick_of_interval(dates)
df
# Out:
# <Response [200]>
# 2023-07-16
# <Response [200]>
# 2023-07-17
# <Response [200]>
# 2023-07-18
# <Response [200]>
# 2023-07-19
# <Response [200]>
# 2023-07-20
# <Response [200]>
# 2023-07-21
# <Response [200]>
# 2023-07-22
# <Response [200]>
# 2023-07-23
# <Response [200]>
# 2023-07-24
# <Response [200]>
# 2023-07-25
# <Response [200]>
# 2023-07-26
# <Response [200]>
# 2023-07-27
# <Response [200]>
# 2023-07-28
# <Response [200]>
# 2023-07-29
# <Response [200]>
# 2023-07-30
# <Response [200]>
# 2023-07-31
# <Response [200]>
# 2023-08-01
# <Response [200]>
# 2023-08-02
# <Response [200]>
# 2023-08-03
# <Response [200]>
# 2023-08-04
# <Response [200]>
# 2023-08-05
# <Response [200]>
# 2023-08-06
# <Response [200]>
# 2023-08-07
# <Response [200]>
# 2023-08-08
# <Response [200]>
# 2023-08-09
# <Response [200]>
# 2023-08-10
# <Response [200]>
# 2023-08-11
# <Response [200]>
# 2023-08-12
# <Response [200]>
# 2023-08-13
# <Response [200]>
# 2023-08-14
# <Response [200]>
# 2023-08-15
# ...

# %%
# DB에 data update
# key를 기준, 기존데이터에 추가, 없으면 새로운 행에 추가
def update_df_2_mongodb(df, collection, key):
    for record in df.to_dict('records'):
        collection.update_one({key: record[key]},{"$set":record}, upsert=True)

# %%
import pymongo
import pandas as pd

client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["coinDB"]
collection = db['BTC-KRW_5min']

update_df_2_mongodb(df, collection, 'candle_date_time_utc')
