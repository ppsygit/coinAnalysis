# %% [markdown]
# ### 방향성 지수, DMI
# ##### 기본개념
# - 주가의 움직임이 추세를 갖고 있는가를 판단하고 그 강도를 측정하고자 쓰는 분석 기법
#
# - 이 지표는 추세 주종형 지표로써 추세의 방향에 따라 매매 전략을 구사하는 방법을 따르고 있다. 대부분의 수익이 좋은 트레이더들은 보합장같은 추세가 약한 시장보다 추세가 강한 시장에서 이익을 많이 얻는다.
# - 추세 주종지표는 가격추세 흐름을 초기에 파악하는데 아주 유용한데 가격상승이 시작될 때 또는 이러한 추세가 진행중일 때 이를 파악할 수 있는 기준을 제공하여 이런 추세에 편승하여 매수, 매도하여 수익을 낼 수 있도록 도와주는 지표를 말한다.
# - DMI를 쓸 때는 반드시 오실레이터 지표와 함께 사용하여 무리한 지표의 신호에 의한 속임수를 피할 수 있는 전략을 구사하여 보합장에서의 빈번한 손실 거래를 줄일 수가 있는 것이다.
#
# ##### 계산 방법
# - DMI의 계산은 만약 시장이 상승추세라고 한다면 금일의 고가는 전일의 고가보다 높게 형성되어야 하며 시장이 하락추세라고 한다면 금일의 저가는 전일의 저가보다 낮게 형성 되어야 한다는 가정을 기초
# - 이 지표에 의한 매매시스템은 +DI 와-DI로 표시되는 인디케이터로 매매시점을 결정 하는데 여기서 DI는 Directional Indicator로 설명될 수 있다.
#
# - PDI(+DI:Plus Directional Movement)는 금일의 고가가 전일의 고가보다 높을 때 금일의 고가와 전일의 고가와의 차이를 의미
# PDI = PDM(금일고가 - 전일고가) /TR
#
# - MDI(-DI:Minus Directional Movement)는 반대로 금일의 저가가 전일의 전가보다 낮을 때 금일의 저가와 전일 저가와의 차이를 의미
# MDI = MDM(전일저가 - 금일저가) /TR
#
# - TR(True range)는 |금일고가 - 금일저가|, |금일고가  - 전일종가|, |금일저가 - 전일종가| 중 가장 큰 값을 말한다.
#
# - n일 간의 PDI는 PDIn = (PDM 합 / TR 합)
#
# #### 매매 기법
#
# - PDI와 MDI는 0~100을 사이 교차하며 움직이며 가격의 상승, 하락의 강도를 표시 한다.
#
# - PDI가 MDI을 아래서 위로 교차하면 매수신호로 보고 +DI가 -DI를 아래로 교차하면 매도신호로 본다
#
# 가격의 상승시도 -> PDI 값의 증가 및 MDI 상향돌파 -> 매수신호
#
# -> PDI는 점점 커지고, MDI는 점점 작아져 라인이 벌어짐 -> PDI의 약화 및 MDI의 상승 -> PDI 값의 MDI 하향돌파 -> 매수 청산
#
# - 윌더의 극점의 법칙 :
# 윌더가 잘못된 매매 신호를 최대한 제거하기 위해 고안한 법칙으로 +DI가 -DI를 상방으로 교차하는 날의 고가를 기준가격으로 정하고 가격이 기준가격을 초과하면 매수신호로 본다. 반대로 +DI가 -DI를 하방으로 교차하는 날의 저가를 기준가격으로 하고 가격이 기준가격의 아래로 초과하면 매도신호로 간주 한다.
#
# - STOP-LOSS(손절매) :
# DMI의 손절매를 방법은 DMI의 매매 방법인 PDI와 MDI의 교차만을 갖고 매매 함으로써 갖는 단점을 커버하기 위한 것이다. 이는 잘못되며 매매의 횟수가 많아지며 실패할 확률을 줄이기 위한 평균적 고수익을 확보하고 추세에 제대로 편승하여 그 이익을 극대화시키기 위함이다.

# %%
import pandas as pd
df = pd.read_csv('DATA/upbit_BTC_prices_2023_days.csv').drop(columns='Unnamed: 0')
df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC           2022-12-05  2022-12-05T09:00:00     22918000.0
# 1    KRW-BTC           2022-12-06  2022-12-06T09:00:00     22729000.0
# 2    KRW-BTC           2022-12-07  2022-12-07T09:00:00     22837000.0
# 3    KRW-BTC           2022-12-08  2022-12-08T09:00:00     22544000.0
# 4    KRW-BTC           2022-12-09  2022-12-09T09:00:00     22918000.0
# ..       ...                  ...                  ...            ...
# 387  KRW-BTC           2023-12-27  2023-12-27T09:00:00     57032000.0
# 388  KRW-BTC           2023-12-28  2023-12-28T09:00:00     57920000.0
# 389  KRW-BTC           2023-12-29  2023-12-29T09:00:00     56904000.0
# 390  KRW-BTC           2023-12-30  2023-12-30T09:00:00     56450000.0
# 391  KRW-BTC           2023-12-31  2023-12-31T09:00:00     56639000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    23150000.0  22685000.0   22725000.0  1670284798929
# ...

# %%
import ta
import ta.utils
high = df['high_price'].astype('float')
low = df['low_price'].astype('float')
close = df['trade_price'].astype('float')
adx = ta.trend.ADXIndicator(high=high, low=low, close=close)

# %%
# import ta
# import ta.utils
# high = df['high_price'].loc[100:].astype('float')
# low = df['low_price'].loc[100:].astype('float')
# close = df['trade_price'].loc[100:].astype('float')
# adx = ta.trend.ADXIndicator(high=high, low=low, close=close)

# %%
# 앞의 10개는 adx 안구해짐
df['ADX'] = adx.adx().astype('float')
df['PDI'] = adx.adx_pos().astype('float')
df['MDI'] = adx.adx_neg().astype('float')
df['candle_date_time_utc'] = pd.to_datetime(df['candle_date_time_utc'])
df = df.loc[df['ADX']!=0]
df.head(30)
# Out:
#      market candle_date_time_utc candle_date_time_kst  opening_price  \
# 27  KRW-BTC           2023-01-01  2023-01-01T09:00:00     21079000.0
# 28  KRW-BTC           2023-01-02  2023-01-02T09:00:00     21128000.0
# 29  KRW-BTC           2023-01-03  2023-01-03T09:00:00     21209000.0
# 30  KRW-BTC           2023-01-04  2023-01-04T09:00:00     21351000.0
# 31  KRW-BTC           2023-01-05  2023-01-05T09:00:00     21589000.0
# 32  KRW-BTC           2023-01-06  2023-01-06T09:00:00     21575000.0
# 33  KRW-BTC           2023-01-07  2023-01-07T09:00:00     21517000.0
# 34  KRW-BTC           2023-01-08  2023-01-08T09:00:00     21539000.0
# 35  KRW-BTC           2023-01-09  2023-01-09T09:00:00     21704000.0
# 36  KRW-BTC           2023-01-10  2023-01-10T09:00:00     21655000.0
# 37  KRW-BTC           2023-01-11  2023-01-11T09:00:00     21916000.0
# 38  KRW-BTC           2023-01-12  2023-01-12T09:00:00     22475000.0
# 39  KRW-BTC           2023-01-13  2023-01-13T09:00:00     23546000.0
# ...

# %%
df['candle_date_time_utc'].value_counts()
# Out:
# candle_date_time_utc
# 2023-01-01    1
# 2023-09-09    1
# 2023-09-07    1
# 2023-09-06    1
# 2023-09-05    1
#              ..
# 2023-05-01    1
# 2023-04-30    1
# 2023-04-29    1
# 2023-04-28    1
# 2023-12-31    1
# Name: count, Length: 365, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
plt.plot(df_mat['candle_date_time_utc'], df_mat['PDI'], color = 'b', label = 'PDI')
plt.plot(df_mat['candle_date_time_utc'], df_mat['MDI'], color = 'r', label = 'MDI')

plt.legend()
plt.show()

# %%
df = df.reset_index(drop=['index'])
df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC           2023-01-01  2023-01-01T09:00:00     21079000.0
# 1    KRW-BTC           2023-01-02  2023-01-02T09:00:00     21128000.0
# 2    KRW-BTC           2023-01-03  2023-01-03T09:00:00     21209000.0
# 3    KRW-BTC           2023-01-04  2023-01-04T09:00:00     21351000.0
# 4    KRW-BTC           2023-01-05  2023-01-05T09:00:00     21589000.0
# ..       ...                  ...                  ...            ...
# 360  KRW-BTC           2023-12-27  2023-12-27T09:00:00     57032000.0
# 361  KRW-BTC           2023-12-28  2023-12-28T09:00:00     57920000.0
# 362  KRW-BTC           2023-12-29  2023-12-29T09:00:00     56904000.0
# 363  KRW-BTC           2023-12-30  2023-12-30T09:00:00     56450000.0
# 364  KRW-BTC           2023-12-31  2023-12-31T09:00:00     56639000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    21171000.0  21002000.0   21123000.0  1672617597561
# ...

# %% [markdown]
# ### PDI, MDI 돌파시점에 매매 해보기

# %%
stat = 'buy'
trade_list = list()
for i in range(len(df)):
    if df.loc[i]['PDI']>=df.loc[i]['MDI'] and stat == 'buy':
        trade_dict = dict()
        trade_dict['buy'] = df.loc[i]['trade_price']
        trade_dict['buy_date'] = df.loc[i]['candle_date_time_utc']
        stat='sell'
    elif df.loc[i]['PDI']<=df.loc[i]['MDI'] and stat == 'sell':
        trade_dict['sell'] = df.loc[i]['trade_price']
        trade_dict['sell_date'] = df.loc[i]['candle_date_time_utc']
        stat='buy'
        trade_list.append(trade_dict)
    else:
        continue
trade_list
# Out:
# [{'buy': 22485000.0,
#   'buy_date': Timestamp('2023-01-11 00:00:00'),
#   'sell': 29579000.0,
#   'sell_date': Timestamp('2023-03-07 00:00:00')},
#  {'buy': 31676000.0,
#   'buy_date': Timestamp('2023-03-13 00:00:00'),
#   'sell': 36337000.0,
#   'sell_date': Timestamp('2023-04-21 00:00:00')},
#  {'buy': 38017000.0,
#   'buy_date': Timestamp('2023-04-26 00:00:00'),
#   'sell': 37255000.0,
#   'sell_date': Timestamp('2023-05-08 00:00:00')},
#  {'buy': 37350000.0,
#   'buy_date': Timestamp('2023-05-28 00:00:00'),
#   'sell': 35823000.0,
#   'sell_date': Timestamp('2023-06-01 00:00:00')},
#  {'buy': 36946000.0,
#   'buy_date': Timestamp('2023-06-20 00:00:00'),
#   'sell': 37892000.0,
#   'sell_date': Timestamp('2023-07-24 00:00:00')},
#  {'buy': 38642000.0,
#   'buy_date': Timestamp('2023-08-01 00:00:00'),
#   'sell': 36588000.0,
#   'sell_date': Timestamp('2023-08-17 00:00:00')},
#  {'buy': 37445000.0,
#   'buy_date': Timestamp('2023-08-29 00:00:00'),
#   'sell': 35502000.0,
# ...

# %%
df_trade = pd.DataFrame(trade_list)
df_trade['profit'] = df_trade['sell']-df_trade['buy']
df_trade
# Out:
#            buy   buy_date        sell  sell_date      profit
# 0   22485000.0 2023-01-11  29579000.0 2023-03-07   7094000.0
# 1   31676000.0 2023-03-13  36337000.0 2023-04-21   4661000.0
# 2   38017000.0 2023-04-26  37255000.0 2023-05-08   -762000.0
# 3   37350000.0 2023-05-28  35823000.0 2023-06-01  -1527000.0
# 4   36946000.0 2023-06-20  37892000.0 2023-07-24    946000.0
# 5   38642000.0 2023-08-01  36588000.0 2023-08-17  -2054000.0
# 6   37445000.0 2023-08-29  35502000.0 2023-08-31  -1943000.0
# 7   35889000.0 2023-09-14  35534000.0 2023-09-24   -355000.0
# 8   35982000.0 2023-09-27  36671000.0 2023-10-11    689000.0
# 9   36968000.0 2023-10-13  58130000.0 2023-12-18  21162000.0
# 10  59351000.0 2023-12-20  58042000.0 2023-12-25  -1309000.0

# %%
df_trade['profit_rate'] = df_trade['profit']/df_trade['sell']*100
df_trade
# Out:
#            buy   buy_date        sell  sell_date      profit  profit_rate
# 0   22485000.0 2023-01-11  29579000.0 2023-03-07   7094000.0    23.983231
# 1   31676000.0 2023-03-13  36337000.0 2023-04-21   4661000.0    12.827146
# 2   38017000.0 2023-04-26  37255000.0 2023-05-08   -762000.0    -2.045363
# 3   37350000.0 2023-05-28  35823000.0 2023-06-01  -1527000.0    -4.262625
# 4   36946000.0 2023-06-20  37892000.0 2023-07-24    946000.0     2.496569
# 5   38642000.0 2023-08-01  36588000.0 2023-08-17  -2054000.0    -5.613862
# 6   37445000.0 2023-08-29  35502000.0 2023-08-31  -1943000.0    -5.472931
# 7   35889000.0 2023-09-14  35534000.0 2023-09-24   -355000.0    -0.999043
# 8   35982000.0 2023-09-27  36671000.0 2023-10-11    689000.0     1.878869
# 9   36968000.0 2023-10-13  58130000.0 2023-12-18  21162000.0    36.404610
# 10  59351000.0 2023-12-20  58042000.0 2023-12-25  -1309000.0    -2.255263

# %%
balance = 1
for i in range(len(df_trade)):
    balance += balance * df_trade.loc[i]['profit_rate']/100 
balance
# Out:
# 1.6132539639626287

# %% [markdown]
# ##### 매매 시점 시각화

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
plt.plot(df_mat['candle_date_time_utc'], df_mat['PDI'], color = 'b', label = 'PDI')
plt.plot(df_mat['candle_date_time_utc'], df_mat['MDI'], color = 'r', label = 'MDI')
for i in range(len(df_trade)):
        plt.axvline(df_trade.loc[i]['buy_date'], color='orangered')
        plt.axvline(df_trade.loc[i]['sell_date'], color='steelblue')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
plt.plot(df_mat['candle_date_time_utc'], df_mat['trade_price'], color = 'black', label = 'trade_price')
plt.plot(df_trade['buy_date'], df_trade['buy'], 'ro')
plt.plot(df_trade['sell_date'], df_trade['sell'], 'bo')
plt.legend()
plt.show()

# %% [markdown]
# ##### PDI 상향, 하향 돌파 시점에 매매시 수익 발생했던 매매

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
plt.plot(df_mat['candle_date_time_utc'], df_mat['trade_price'], color = 'black', label = 'trade_price')
plt.plot(df_trade.loc[df_trade['profit_rate']>0]['buy_date'],df_trade.loc[df_trade['profit_rate']>0]['buy'], 'ro')
plt.plot(df_trade.loc[df_trade['profit_rate']>0]['sell_date'],df_trade.loc[df_trade['profit_rate']>0]['sell'], 'bo')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
for i in range(len(df_trade)):
    if df_trade.loc[i]['profit_rate']>0:
        plt.axvline(df_trade.loc[i]['buy_date'], color='orangered')
        plt.axvline(df_trade.loc[i]['sell_date'], color='steelblue')

plt.plot(df_mat['candle_date_time_utc'], df_mat['PDI'], color='b', label = 'PDI')
plt.plot(df_mat['candle_date_time_utc'], df_mat['MDI'], color='r', label = 'MDI')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
for i in range(len(df_trade)):
    if df_trade.loc[i]['profit_rate']>=0:
        plt.axvline(df_trade.loc[i]['buy_date'], color='orangered')
        plt.axvline(df_trade.loc[i]['sell_date'], color='steelblue')

plt.plot(df_mat['candle_date_time_utc'], df_mat['ADX'], color='g', label = 'ADX')
plt.legend()
plt.show()

# %% [markdown]
# ##### PDI 상향, 하향 돌파 시점에 매매시 손해 발생했던 매매

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
plt.plot(df_mat['candle_date_time_utc'], df_mat['trade_price'], color = 'black', label = 'trade_price')
plt.plot(df_trade.loc[df_trade['profit_rate']<0]['buy_date'],df_trade.loc[df_trade['profit_rate']<0]['buy'], 'ro')
plt.plot(df_trade.loc[df_trade['profit_rate']<0]['sell_date'],df_trade.loc[df_trade['profit_rate']<0]['sell'], 'bo')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
for i in range(len(df_trade)):
    if df_trade.loc[i]['profit_rate']<0:
        plt.axvline(df_trade.loc[i]['buy_date'], color='orangered')
        plt.axvline(df_trade.loc[i]['sell_date'], color='steelblue')

plt.plot(df_mat['candle_date_time_utc'], df_mat['PDI'], color='b', label = 'PDI')
plt.plot(df_mat['candle_date_time_utc'], df_mat['MDI'], color='r', label = 'MDI')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(14,6))
df_mat = df.copy()
for i in range(len(df_trade)):
    if df_trade.loc[i]['profit_rate']<0:
        plt.axvline(df_trade.loc[i]['buy_date'], color='orangered')
        plt.axvline(df_trade.loc[i]['sell_date'], color='steelblue')

plt.plot(df_mat['candle_date_time_utc'], df_mat['ADX'], color='g', label = 'ADX')
plt.legend()
plt.show()

# %%
df_trade['profit_rate'].describe()
# Out:
# count    11.000000
# mean      5.176485
# std      13.674575
# min      -5.613862
# 25%      -3.258944
# 50%      -0.999043
# 75%       7.661858
# max      36.404610
# Name: profit_rate, dtype: float64
